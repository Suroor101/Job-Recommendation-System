# %%
#import library and module
import pandas as pd
from resume_screening import resparser, match
# Out:
# c:\Users\LENOVO\Desktop\Job Recommendation System\.venv\Lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.2 and is incompatible with the current spaCy version (2.3.9). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)

# %%
from nltk.corpus import stopwords
stopw  = set(stopwords.words('english'))

# %%
#read indeed job vacancy data
job = pd.read_csv('data/combined.csv')
job['test'] = job['description'].apply(lambda x: ' '.join([word for word in str(x).split() if len(word)>2 and word not in (stopw)]))

# %%
df = job.drop_duplicates(subset='test').reset_index(drop=True)
df.head()
# Out:
#                                                title                company  \
# 0  Job Opening For Python Developer | Trigent Sof...       Trigent Software
# 1                                   Python Developer  VN2 Solutions Pvt Ltd
# 2  HCL Hiring For Python Developer - Bangalore / ...                HCLTech
# 3  HCL Hiring For Python  Developer -Bangalore / ...                HCLTech
# 4  HCL Hiring For Python Developer For Bangalore ...                HCLTech
#
#                                             location         salary  \
# 0                    Bangalore/ Bengaluru, Karnataka    3-4 Lacs PA
# 1                                Bangalore/Bengaluru    4-8 Lacs PA
# 2  Hybrid - Chennai, Tamil Nadu, Bangalore/ Benga...  Not disclosed
# 3              Hybrid - Chennai, Bangalore/Bengaluru  Not disclosed
# 4              Hybrid - Chennai, Bangalore/Bengaluru  15-30 Lacs PA
#
#   experience                                               link  \
# 0    0-0 Yrs  https://www.naukri.com/job-listings-opening-fo...
# 1    0-0 Yrs  https://www.naukri.com/job-listings-python-dev...
# 2   6-10 Yrs  https://www.naukri.com/job-listings-hcl-hiring...
# 3   5-10 Yrs  https://www.naukri.com/job-listings-hcl-hiring...
# 4   5-10 Yrs  https://www.naukri.com/job-listings-hcl-hiring...
#
#                                          description  \
# 0  Note: Python Certification is must (Freshers p...
# 1  Qualifications for a Python Developer: . Bache...
# 2  Candidate must be good at writing software usi...
# 3  HCL is Hiring for Python Developer for one of ...
# 4  HCL is Hiring for Python Developerfor one of t...
#
#                                               skills  \
# 0                        software,python,development
# 1  python,Django,Python Framework,Development,Fra...
# 2            API,Python,development,rest,hiring,FAST
# 3  Rest API,Python,microservices,rest,postgresql,...
# 4  Python,api,hiring,linux,nms,snmp,postgresql,ne...
#
#                                                 test
# 0  Note: Python Certification must (Freshers pass...
# 1  Qualifications Python Developer: Bachelors mas...
# 2  Candidate must good writing software using one...
# 3  HCL Hiring Python Developer one leading produc...
# 4  HCL Hiring Python Developerfor one leading pro...

# %%
test = (df['test'].values.astype('U'))

# %%
print("There are {} job vacancy list scrapped from id.indeed.com".format(df.shape[0]))
# Out:
# There are 3274 job vacancy list scrapped from id.indeed.com

# %% [markdown]
# # Input CV & Preprocessing

# %%
resumeList = []
similarityPercentage =[]

# %%
#input the resume or CV file
filled = input()
resumeList.append(filled)
skills = resparser.skill("instance/resume_files/{}".format(filled))
# Out:
# 2023-06-11 18:56:47,469 [MainThread  ] [ERROR]  Unable to run java; is it installed?
# ERROR:tika.tika:Unable to run java; is it installed?
# 2023-06-11 18:56:47,471 [MainThread  ] [ERROR]  Failed to receive startup confirmation from startServer.
# ERROR:tika.tika:Failed to receive startup confirmation from startServer.
# ERROR:root:Error in tika installation:: Unable to start Tika server.
# ERROR:root:--------------------------
# ERROR:root:Install java for better result

# %%
skills.append(match.preprocessing(skills[0]))
del skills[0]

print("SKILLS LIST:\n",skills)
# Out:
# SKILLS LIST:
#  ['ux social media online dsc ux design organization visual design moc figma user experience app design interview google wireframing web design building instagram investors developers user interface design ug space feeds content design testing user experience design ued gsm teaching media design experience design mastery digital mobile usability banners illustration java prototype usability testing linkedin mobile applications promotional internships web training manuals graphic design materials sketching higher education interfaces options machine learning learning export']

# %% [markdown]
# # Model KNN - Minkowski Metric

# %%
#Train the KNN model using Minkowski Metric
matches = match.knearestNeighbors(skills, test)
matches = pd.DataFrame(matches, columns=['Match confidence'])

# %%
#Job Vacancy Recommendation
result_minkowski = df[['title','company','skills']].copy()
result_minkowski['match'] = matches['Match confidence'].copy()
result_minkowski = result_minkowski.sort_values('match').reset_index(drop=True).head(20)
result_minkowski
# Out:
#                          title                     company  \
# 0             UX / UI Designer                MAQ Software
# 1        Senior UI/UX Designer  Cabot Technology Solutions
# 2      POSITION UX/UI DESIGNER          Triad Technologies
# 3               UI/UX Designer                   Arokia It
# 4        Junior UI/UX Designer                Anita Dongre
# 5               UI/UX Designer              Envizon Studio
# 6               UI/UX designer                   Tecnotree
# 7             UI / UX Designer             Elephant Design
# 8             UI / UX Designer          Highrise Solutions
# 9       Boiler Design Engineer       Perfect People Search
# 10            UX / UI Designer               AutomateBuddy
# 11       Sr . UI / UX Designer                       2Base
# 12  Mechanical Design Engineer                   LD Square
# 13      Piping Stress Engineer                    Randstad
# 14            UI / UX Designer                    Benchire
# 15              UI/UX Designer        Appdest Technologies
# 16               SIL Engineers                  Tata Elxsi
# 17                UX/UI Intern                Learnmall.in
# 18      UI/UX Product Designer       KnowledgeHut - upGrad
# 19              UX/UI Designer       Consleague Consulting
#
#                                                skills  match
# 0   UX,cs,adobe,photoshop,adobe suite,figma,wirefr...   0.74
# 1   product design,pdf,ux,ui,user interface design...   0.78
# 2   ui/ux,cs,visual design,product design,design,a...   0.79
# 3   photoshop,layout,ui/ux,android,html,prototype,...   0.81
# 4   development,ui,research,usability,user flows,w...   0.81
# 5       ui/ux,web technologies,ux design,design,ux,ui   0.81
# 6   interpersonal skills,design,google analytics,g...   0.81
# 7   graphics,interaction design,ui,design,digital ...   0.81
# 8   mysql,ui and ux,ui/ux,html,software testing,us...   0.82
# 9   Boiler Pressure Parts,Boiler Design,Heat Excha...   0.82
# 10  html,ui,adobe creative suite,illustrator,agile...   0.82
# 11  analysis,crm,time managements,ux design,creati...   0.82
# 12  Solid Works,AutoCAD Mechanical,mechanical,draf...   0.83
# 13  caesar ii,Stress Analysis,piping,piping stress...   0.83
# 14  ux,ux design,ui/ux,ui and ux,ui,design,user in...   0.83
# 15     c,sql,python,oracle,xml,six sigma,ux design,ui   0.83
# 16                                   canoe,sil,dspace   0.84
# 17  collaterals,media,marketing collaterals,ui,dig...   0.84
# 18  Ui/Ux,Typography,Visual Design,design principl...   0.84
# 19  jquery,design,photoshop,ux,seo,analytics,compu...   0.84

# %% [markdown]
# # Model Cosine Similarity

# %%
df['clean'] = df['test'].apply(match.preprocessing)
jobdesc = (df['clean'].values.astype('U'))

# %%
count_matrix = match.vectorizing(skills[0], jobdesc)
matchPercentage = match.coSim(count_matrix)
matchPercentage = pd.DataFrame(matchPercentage, columns=['Skills Match'])

# %%
#Job Vacancy Recommendations
result_cosine = df[['title','company','skills']]
result_cosine = result_cosine.join(matchPercentage)
result_cosine = result_cosine.sort_values('Skills Match', ascending=False).reset_index(drop=True).head(20)
result_cosine
# Out:
#                                            title  \
# 0                          Junior UI/UX Designer
# 1       Industry X - Aero Engineering - ESI - 09
# 2                                 UI/UX Designer
# 3                               UI / UX Designer
# 4                                 UI/UX Designer
# 5                          Senior UI/UX Designer
# 6                                 UI/UX Designer
# 7   Design UI /UX Lead (Digital Product) @ Noida
# 8                               UI / UX Designer
# 9                      UI UX Design Lead @ Noida
# 10                  System Designer (Electrical)
# 11                         Senior Designer UX/UI
# 12                              UI / UX Designer
# 13                              UI / UX Designer
# 14                  Intern/Junior UX/UI Designer
# 15                              UX / UI Designer
# 16                        UI/UX Product Designer
# 17                                UI/UX Designer
# 18                         Senior UI/UX Designer
# 19          Technology - Senior UI / UX Designer
#
#                                company  \
# 0                         Anita Dongre
# 1                            Accenture
# 2             Vibgyor Group of Schools
# 3                      Elephant Design
# 4                              4i Apps
# 5           Cabot Technology Solutions
# 6                        ModeFinServer
# 7               Brainsearch Consulting
# 8                           Skill Lens
# 9               Brainsearch Consulting
# 10                       Capleo Global
# 11           Scketch Digital Solutions
# 12                      T2 Innovations
# 13                    Invints Infotech
# 14  Badho Technologies Private Limited
# 15                       AutomateBuddy
# 16               KnowledgeHut - upGrad
# 17              Cognerium Robotic Labs
# 18                     Mitratech India
# 19           Indiassetz Infra Services
#
#                                                skills  Skills Match
# 0   development,ui,research,usability,user flows,w...         59.94
# 1   Aero Engineering,RCA,VPM,3d,quality management...         58.07
# 2   Ui/Ux,Video Editing,graphic designing,corel dr...         56.87
# 3   graphics,interaction design,ui,design,digital ...         56.34
# 4   tool design,tools,illustrator,saas,technology ...         55.06
# 5   product design,pdf,ux,ui,user interface design...         54.55
# 6   design,ux,visual design,ui,application,analyti...         54.32
# 7   Design,Ui/Ux,Visual Graphic,visual design,Ui A...         53.20
# 8   time managements,adobe,html,user interface des...         51.91
# 9   optimal design,UIUX,UI,UX design,storyboards,U...         50.47
# 10  Creative,Software testing,Engineering,Creative...         50.31
# 11  management,ux,web technologies,user interface ...         49.36
# 12  interfaces,ui/ux,tools,adobe,adobe acrobat,ux ...         48.47
# 13  html,project,ui,illustrator,usability testing,...         48.37
# 14  ui/ux,ux,interface design,illustrator,ill,user...         46.28
# 15  html,ui,adobe creative suite,illustrator,agile...         46.17
# 16  Ui/Ux,Typography,Visual Design,design principl...         45.94
# 17  Creativity,adobe xd,time management,ux,sketchi...         45.94
# 18  Creative,Visual Design,Quality,Product design,...         45.94
# 19  test management,interaction design,management,...         45.88

# %% [markdown]
# # Comparing between Minkowski Metric vs Cosine Similarity

# %%
data = [result_minkowski[['title','company']], result_cosine[['title','company']]]
headers = ['Minkowski','Cosine Similarity']
df_compare = pd.concat(data, axis = 1, keys = headers)
df_compare
# Out:
#                      Minkowski                              \
#                          title                     company
# 0             UX / UI Designer                MAQ Software
# 1        Senior UI/UX Designer  Cabot Technology Solutions
# 2      POSITION UX/UI DESIGNER          Triad Technologies
# 3               UI/UX Designer                   Arokia It
# 4        Junior UI/UX Designer                Anita Dongre
# 5               UI/UX Designer              Envizon Studio
# 6               UI/UX designer                   Tecnotree
# 7             UI / UX Designer             Elephant Design
# 8             UI / UX Designer          Highrise Solutions
# 9       Boiler Design Engineer       Perfect People Search
# 10            UX / UI Designer               AutomateBuddy
# 11       Sr . UI / UX Designer                       2Base
# 12  Mechanical Design Engineer                   LD Square
# 13      Piping Stress Engineer                    Randstad
# 14            UI / UX Designer                    Benchire
# 15              UI/UX Designer        Appdest Technologies
# 16               SIL Engineers                  Tata Elxsi
# 17                UX/UI Intern                Learnmall.in
# 18      UI/UX Product Designer       KnowledgeHut - upGrad
# 19              UX/UI Designer       Consleague Consulting
#
#                                Cosine Similarity  \
#                                            title
# 0                          Junior UI/UX Designer
# 1       Industry X - Aero Engineering - ESI - 09
# 2                                 UI/UX Designer
# 3                               UI / UX Designer
# 4                                 UI/UX Designer
# 5                          Senior UI/UX Designer
# 6                                 UI/UX Designer
# 7   Design UI /UX Lead (Digital Product) @ Noida
# 8                               UI / UX Designer
# 9                      UI UX Design Lead @ Noida
# 10                  System Designer (Electrical)
# 11                         Senior Designer UX/UI
# 12                              UI / UX Designer
# 13                              UI / UX Designer
# 14                  Intern/Junior UX/UI Designer
# 15                              UX / UI Designer
# 16                        UI/UX Product Designer
# 17                                UI/UX Designer
# 18                         Senior UI/UX Designer
# 19          Technology - Senior UI / UX Designer
#
#
#                                company
# 0                         Anita Dongre
# 1                            Accenture
# 2             Vibgyor Group of Schools
# 3                      Elephant Design
# 4                              4i Apps
# 5           Cabot Technology Solutions
# 6                        ModeFinServer
# 7               Brainsearch Consulting
# 8                           Skill Lens
# 9               Brainsearch Consulting
# 10                       Capleo Global
# 11           Scketch Digital Solutions
# 12                      T2 Innovations
# 13                    Invints Infotech
# 14  Badho Technologies Private Limited
# 15                       AutomateBuddy
# 16               KnowledgeHut - upGrad
# 17              Cognerium Robotic Labs
# 18                     Mitratech India
# 19           Indiassetz Infra Services

# %%
job_compare = pd.merge(df_compare['Minkowski'], df_compare['Cosine Similarity'], how = 'inner')
job_compare
# Out:
#                     title                     company
# 0   Senior UI/UX Designer  Cabot Technology Solutions
# 1   Junior UI/UX Designer                Anita Dongre
# 2        UI / UX Designer             Elephant Design
# 3        UX / UI Designer               AutomateBuddy
# 4  UI/UX Product Designer       KnowledgeHut - upGrad

# %%
similarityPercentage.append((job_compare.shape[0]/df_compare.shape[0])*100)

# %%
print(resumeList)
print(similarityPercentage)
# Out:
# ['ui/ux.pdf', 'uiux.pdf']
# [25.0]

# %%
modelSimilarity = pd.DataFrame(list(zip(resumeList, similarityPercentage)),columns =['Resume Name', 'Similarity'])
print(modelSimilarity)
# Out:
#   Resume Name  Similarity
# 0   ui/ux.pdf        25.0

# %%
print("The average similarity between the 2 metrics above is: ", modelSimilarity["Similarity"].mean())
# Out:
# The average similarity between the 2 metrics above is:  25.0

# %%
waitress-serve --listen=127.0.0.1:5000 app:app
